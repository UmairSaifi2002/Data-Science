# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                 Actor                      Film  Year            Genre  \
# 0      Shah Rukh Khan                   Pathaan  2023           Action
# 1         Salamn Khan           Tiger Zinda Hai  2017           Action
# 2          Aamir Khan                    Dangal  2016        Biography
# 3       Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4       Ranveer Singh                  Padmavat  2018       Historical
# 5   Ayushmaan Khurana                 Andhadhun  2018         Thriller
# 6        Rajkumar Rao                     Stree  2018    Horror Comedy
# 7      Hrithik Roshan                       War  2019           Action
# 8        Akshay Kumar                 Good Newz  2019           Comedy
# 9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10       Varun Dhavan     Badrinath ki Dulhania  2017  Romantic Comedy
# 11      Vicky Kaushal  URI: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df["Actor"], type(df["Actor"])
# Out:
# (0        Shah Rukh Khan
#  1           Salamn Khan
#  2            Aamir Khan
#  3         Ranbir Kapoor
#  4         Ranveer Singh
#  5     Ayushmaan Khurana
#  6          Rajkumar Rao
#  7        Hrithik Roshan
#  8          Akshay Kumar
#  9         Kartik Aaryan
#  10         Varun Dhavan
#  11        Vicky Kaushal
#  Name: Actor, dtype: object,
#  pandas.core.series.Series)

# %%
df[["Actor", "IMDb"]]
# Out:
#                 Actor  IMDb
# 0      Shah Rukh Khan   7.2
# 1         Salamn Khan   6.0
# 2          Aamir Khan   8.4
# 3       Ranbir Kapoor   5.6
# 4       Ranveer Singh   7.0
# 5   Ayushmaan Khurana   8.3
# 6        Rajkumar Rao   7.5
# 7      Hrithik Roshan   6.5
# 8        Akshay Kumar   7.0
# 9       Kartik Aaryan   5.9
# 10       Varun Dhavan   6.1
# 11      Vicky Kaushal   8.2

# %%
df.loc[1] # It will find the row lables
# Out:
# Actor                       Salamn Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.0
# Name: 1, dtype: object

# %%
df.iloc[1] # It will find using the index
# Out:
# Actor                       Salamn Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.0
# Name: 1, dtype: object

# %%
df.loc[8, 'Genre']
# Out:
# 'Comedy'

# %%
df.iloc[8,3]
# Out:
# 'Comedy'

# %%
df.loc[0:2, ['Actor', 'Film', 'IMDb']]
# Out:
#             Actor             Film  IMDb
# 0  Shah Rukh Khan          Pathaan   7.2
# 1     Salamn Khan  Tiger Zinda Hai   6.0
# 2      Aamir Khan           Dangal   8.4

# %%
df.at[0,'Actor']
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0,0]
# Out:
# 'Shah Rukh Khan'

# %%
df[df['IMDb']>6]
# Out:
#                 Actor                      Film  Year            Genre  \
# 0      Shah Rukh Khan                   Pathaan  2023           Action
# 2          Aamir Khan                    Dangal  2016        Biography
# 4       Ranveer Singh                  Padmavat  2018       Historical
# 5   Ayushmaan Khurana                 Andhadhun  2018         Thriller
# 6        Rajkumar Rao                     Stree  2018    Horror Comedy
# 7      Hrithik Roshan                       War  2019           Action
# 8        Akshay Kumar                 Good Newz  2019           Comedy
# 10       Varun Dhavan     Badrinath ki Dulhania  2017  Romantic Comedy
# 11      Vicky Kaushal  URI: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# ...

# %%
df[df['IMDb']>6]['Actor']
# Out:
# 0        Shah Rukh Khan
# 2            Aamir Khan
# 4         Ranveer Singh
# 5     Ayushmaan Khurana
# 6          Rajkumar Rao
# 7        Hrithik Roshan
# 8          Akshay Kumar
# 10         Varun Dhavan
# 11        Vicky Kaushal
# Name: Actor, dtype: object

# %%
df[(df['IMDb']>6) & (df['Year']>2019)]
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
# .query() it returns a copy not a view.
# copy means when we make changes in copy it donot reflect in the main dataset.
# but if make any changes in view it reflect back to the main dataset. 
df.query('Year > 2018 and IMDb > 6')
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                 Good Newz  2019  Comedy
# 11   Vicky Kaushal  URI: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
