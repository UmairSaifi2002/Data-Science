# %%
name = "Umair Saifi"

# %%
name
# Out:
# 'Umair Saifi'

# %%
name.upper()
# Out:
# 'UMAIR SAIFI'

# %%
name.endswith("r")
# Out:
# False

# %%
name.endswith("j")
# Out:
# False

# %%
name.count("a")
# Out:
# 2

# %%
name.split(" ")
# Out:
# ['Umair', 'Saifi']

# %%
len(name)
# Out:
# 11
