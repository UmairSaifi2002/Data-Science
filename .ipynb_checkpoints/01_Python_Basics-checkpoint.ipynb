# %%
a = 5

# %%
b = 6

# %%
value = a+b
print(value)
# Out:
# 11

# %%
name = "Umair"

# %%
print("Hello Pyhton")
# Out:
# Hello Pyhton

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
num1 = "4566"
num2 = "7599"
num1 + num2
# Out:
# '45667599'

# %%
int(num1) + int(num2) # Type Casting
# Out:
# 12165
